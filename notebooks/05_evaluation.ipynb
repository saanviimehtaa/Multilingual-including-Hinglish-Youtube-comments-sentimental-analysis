# %%
import sys
sys.path.append("..")
import warnings
warnings.filterwarnings("ignore")

import joblib
import numpy as np
import pandas as pd
from scipy import sparse

from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from utils import plot_confusion_matrix

# %%
import utils
print(dir(utils))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'load_cleaned_data', 'load_raw_data', 'np', 'pd', 'plot_confusion_matrix', 'plt']

# %%
best_model = joblib.load("../data/best_sentiment_model.joblib")
vectorizer = joblib.load("../data/tfidf_vectorizer.joblib")
le = joblib.load("../data/label_encoder.joblib")

X_test = sparse.load_npz("../data/X_test.npz")
y_test = pd.read_csv("../data/y_test.csv")["label"]

print("Model:", type(best_model).__name__)
print("Test set shape:", X_test.shape)
# Out:
# Model: LinearSVC
# Test set shape: (18096, 40000)

# %%
preds = best_model.predict(X_test)
print(classification_report(y_test, preds, target_names=le.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.67      0.71      0.69      6480
#      Neutral       0.61      0.63      0.62      5680
#     Positive       0.77      0.69      0.73      5936
#
#     accuracy                           0.68     18096
#    macro avg       0.69      0.68      0.68     18096
# weighted avg       0.69      0.68      0.68     18096

# %%
cm = confusion_matrix(y_test, preds)
plot_confusion_matrix(cm, le.classes_, title=f"Confusion Matrix - {type(best_model).__name__}")
plt.show()
